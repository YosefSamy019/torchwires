# %% [markdown]
# # Import

# %%
import sys

sys.path.append(r"D:\Materials\AI\Projects\Lib\torchwires\src")

from torchwires import Repo
from torchwires import BaseCallback
from torchwires import Trainer
from torchwires import Visualizer

# %%
import torch
from torch.utils.data import DataLoader, Dataset

import numpy as np

# %% [markdown]
# # Create

# %%
repo_1 = Repo(
    repo_name="full_test_1",
)

repo_2 = Repo(
    repo_name="full_test_2",
)

repo_3 = Repo(
    repo_name="full_test_3",
)
# Out:
# History loaded: path=full_test_1\exp_1\history.json
# History Features loaded: path=full_test_1\exp_1\history_tracked.json
# History loaded: path=full_test_2\exp_1\history.json
# History Features loaded: path=full_test_2\exp_1\history_tracked.json
# History loaded: path=full_test_3\exp_1\history.json
# History Features loaded: path=full_test_3\exp_1\history_tracked.json

# %% [markdown]
# # Visuals

# %%
Visualizer.visualize_comparison(
    [repo_1, repo_2, repo_3],
)

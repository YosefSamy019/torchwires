# %%
import sys
sys.path.append(r"D:\Materials\AI\Projects\Lib\torchwires\src")

from torchwires import Repo, Visualizer, Runner, PassState

# %%
repo_0 = Repo(
    repo_name='repo_0',
)

repo_1 = Repo(
    repo_name='repo_1',
)
# Out:
# History loaded: path=repo_0\exp_1\history.json
# History loaded: path=repo_1\exp_1\history.json

# %%
Visualizer.visualize_comparison(
    repos = [repo_0, repo_1],
)
